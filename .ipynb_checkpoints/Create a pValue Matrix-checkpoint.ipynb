# %% [markdown]
# ## Create a Matrix with Pairwise Statistical Tests

# %% [markdown]
# **Import the Basics**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind
# %matplotlib inline

# %% [markdown]
# **Import Table with Boxplot Data**

# %%
boxplots = pd.read_csv('data_examples/fruits.txt', sep = '\t')
boxplots
# Out:
#     banana  peach  apple  appricot  melon
# 0    2.180   3.83  2.050     2.050  2.010
# 1    1.350   3.15  0.505     0.505  3.620
# 2    0.412   5.02  2.210     2.210  2.530
# 3    0.418   4.52  1.220     1.220  1.220
# 4    1.350   2.40  0.412     2.010  0.412
# 5    1.040   3.83  0.418     3.620  0.418
# 6    0.905   4.67  1.350     2.530  1.350
# 7    2.180   2.92  1.040     1.220  1.040
# 8    1.350   3.96  0.905       NaN  0.905
# 9    0.412   1.72    NaN       NaN  2.530
# 10     NaN    NaN    NaN       NaN  1.220

# %% [markdown]
# **Function to Compute Two-Tailed T-test for all Possible Pairwise Combination** <br>
# and to plot the data if needed

# %%
def pvals_matrix(boxplots_table):
    '''generates a paiwise comparission of all columns'''
    
    pvals_table = []

    for name1,values1 in boxplots_table.iteritems():
        col1 = values1.dropna()

        for name2,values2 in boxplots_table.iteritems():
            col2 = values2.dropna()

            t_statistic,pval = ttest_ind(col1,col2, equal_var = False)
            name = name1,name2
            pvals_table.append([name1,name2, pval])
    
    pvals_table = pd.DataFrame(pvals_table)
    pvals_table.columns = ['sample1', 'sample2','pval']
    
    #re-shape table into a matrix
    pvals_matrix = pvals_table.pivot(index = 'sample2', columns = 'sample1', values = 'pval')
    
    # just a fancy way to show the data
    def color_significance(value):
        """ colors numbers green if p<0.05"""
        if value < 0.05:
            color = 'green'
        else:
            color = 'black'
        return 'color: %s' % color

    pvals_matrix = pvals_matrix.style.applymap(color_significance)

    return pvals_matrix

def plot_boxplots(boxplots_data):
    '''plot boxplots'''

    fig, ax = plt.subplots(figsize = (boxplots_data.shape[1],3), dpi = 150)

    mycolors = ['red','blue','green','orange','magenta']
    #sns.set_palette(mycolors)

    sns.boxplot(data = boxplots_data, linewidth = 1, palette = mycolors, width = 0.5, boxprops = dict(alpha=0.7), ax = ax)
    sns.stripplot( data = boxplots_data ,size = 6, palette = mycolors, jitter=True, alpha = 0.8, edgecolor = 'black', linewidth = 1, ax = ax)

    plt.tick_params(direction = 'inout', bottom=False, right = False, width = 1)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    #plt.ylabel('y axis', fontsize=12)
    #plt.ylim([0,6]);

# %% [markdown]
# **Call Functions**

# %%
plot_boxplots(boxplots)  
pvals_matrix(boxplots)
# Out:
# <style  type="text/css" >
#     #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow0_col0 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow0_col1 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow0_col2 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow0_col3 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow0_col4 {
#             color:  green;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow1_col0 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow1_col1 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow1_col2 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow1_col3 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow1_col4 {
#             color:  green;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow2_col0 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow2_col1 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow2_col2 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow2_col3 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow2_col4 {
#             color:  green;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow3_col0 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow3_col1 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow3_col2 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow3_col3 {
#             color:  black;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow3_col4 {
#             color:  green;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow4_col0 {
#             color:  green;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow4_col1 {
#             color:  green;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow4_col2 {
#             color:  green;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow4_col3 {
#             color:  green;
#         }    #T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow4_col4 {
#             color:  black;
#         }</style><table id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176c" ><thead>    <tr>        <th class="index_name level0" >sample1</th>        <th class="col_heading level0 col0" >apple</th>        <th class="col_heading level0 col1" >appricot</th>        <th class="col_heading level0 col2" >banana</th>        <th class="col_heading level0 col3" >melon</th>        <th class="col_heading level0 col4" >peach</th>    </tr>    <tr>        <th class="index_name level0" >sample2</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176clevel0_row0" class="row_heading level0 row0" >apple</th>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow0_col1" class="data row0 col1" >0.070792</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow0_col2" class="data row0 col2" >0.90646</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow0_col3" class="data row0 col3" >0.248988</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow0_col4" class="data row0 col4" >1.46907e-05</td>
#             </tr>
#             <tr>
#                         <th id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176clevel0_row1" class="row_heading level0 row1" >appricot</th>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow1_col0" class="data row1 col0" >0.070792</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow1_col1" class="data row1 col1" >1</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow1_col2" class="data row1 col2" >0.078967</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow1_col3" class="data row1 col3" >0.447068</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow1_col4" class="data row1 col4" >0.00269113</td>
#             </tr>
#             <tr>
#                         <th id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176clevel0_row2" class="row_heading level0 row2" >banana</th>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow2_col0" class="data row2 col0" >0.90646</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow2_col1" class="data row2 col1" >0.078967</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow2_col3" class="data row2 col3" >0.279011</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow2_col4" class="data row2 col4" >1.51573e-05</td>
#             </tr>
#             <tr>
#                         <th id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176clevel0_row3" class="row_heading level0 row3" >melon</th>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow3_col0" class="data row3 col0" >0.248988</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow3_col1" class="data row3 col1" >0.447068</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow3_col2" class="data row3 col2" >0.279011</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow3_col3" class="data row3 col3" >1</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow3_col4" class="data row3 col4" >0.000232358</td>
#             </tr>
#             <tr>
#                         <th id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176clevel0_row4" class="row_heading level0 row4" >peach</th>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow4_col0" class="data row4 col0" >1.46907e-05</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow4_col1" class="data row4 col1" >0.00269113</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow4_col2" class="data row4 col2" >1.51573e-05</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow4_col3" class="data row4 col3" >0.000232358</td>
#                         <td id="T_d9dbe35a_9c3c_11e9_b3dd_5ce0c580176crow4_col4" class="data row4 col4" >1</td>
#             </tr>
#     </tbody></table>
